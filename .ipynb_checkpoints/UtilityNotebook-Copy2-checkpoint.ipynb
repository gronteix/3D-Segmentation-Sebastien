# %%
import os
import numpy as np
import networkx as nx

import process
import pandas

# %% [markdown]
# # Chip analysis
#
# The following notebook is an analysis notebook. It has been conceived to order and analyse a dump of confocal images. All questions concerning the code should be emailed to gustave.ronteix@pasteur.fr.

# %% [markdown]
# These cells are to be used as fitting parameters for the cell

# %%
path = r'\\atlas.pasteur.fr\Multicell\Gustave\fusionGustave\TIFF BIS\1\19'

livePosition = 2
green = 0
orange = 1

channels = [livePosition, green, orange]

zRatio = 1/6
r = 12
d = 30
pxtoum = 1/3

dX = 2*(int(r/pxtoum)//2)+1
dY = 2*(int(r/pxtoum)//2)+1
dZ = 2*(int(zRatio*r/pxtoum)//2)+1

rNoyau = (dZ, dX, dY)

dX = 2*(int(d/pxtoum)//2)+1
dY = 2*(int(d/pxtoum)//2)+1
dZ = 2*(int(zRatio*d/pxtoum)//2)+1

dCells = (dZ, dX, dY)

minmass = 3000

# %%
import spheroid

Sph = spheroid.spheroid(path, '1', '19', zRatio, r, d,pxtoum, minmass)
    # Initialize spheroid

if len(channels) == 3: # Improve dependancy on channel number...

    Sph._loadImage(channels[0], 'NucImage') # Load live cells
    Sph._loadImage(channels[1], 'GreenImage') # Load green cells
    Sph._loadImage(channels[2], 'OrangeImage') # Load orange cells

else: print("Wrong number of color channels")

print('image made, starting nuclei ID')
# Out:
# image made, starting nuclei ID

# %%
rNoyau
# Out:
# (7, 37, 37)

# %%
from trackpy import preprocessing
import trackpy

df = trackpy.locate(Sph.NucImage[:,:,:], rNoyau, minmass=None, maxsize=None, separation=None, noise_size=2, 
                    smoothing_size=None, threshold=None, invert=False, percentile=64, topn=180, 
                    preprocess=True, max_iterations=10, filter_before=None, filter_after=None, characterize=True, 
                    engine='numba')

# %%
import matplotlib.pyplot as plt
from skimage import exposure
from scipy.ndimage import gaussian_filter

fd = df.loc[df['mass'] > minmass]

fd =fd.loc[((fd['x'] -fd['x'].mean())**2 < 4*fd['x'].std()**2) &
          ((fd['y'] -fd['y'].mean())**2 < 4*fd['y'].std()**2)]

img_eq = exposure.equalize_hist(Sph.NucImage[50,250:1750,250:1750])
im =  gaussian_filter(img_eq, sigma=2)

ax, fig = plt.subplots(figsize = (16,16))
plt.imshow(im)
plt.scatter(fd['x']-250, fd['y']-250, c = 'r', s = 5)

# %% [markdown]
# ### Processing
#
# The grunt functions are called from process.
#
# Attention: verify the channel order.

# %%
path = r'\\atlas.pasteur.fr\Multicell\Gustave\fusionGustave\TIFF BIS'
spheroidFolder = '1'
timeFolder = '19'

# %%
process._sortFiles(path)

# %%
process._makeSingleSpheroidClass(path, spheroidFolder, timeFolder, zRatio, rNoyau,
    dCells, pxtoum, channels, minmass)
# Out:
# prep image: 1 folder and time 19
# image made, starting nuclei ID
# nuclei gotten, make spheroid
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-41-c9058673bf24> in <module>
#       1 process._makeSingleSpheroidClass(path, spheroidFolder, timeFolder, zRatio, rNoyau,
# ----> 2     dCells, pxtoum, channels, minmass)
#
# ~\Documents\Python Scripts\3D-segmentation-Seb\process.py in _makeSingleSpheroidClass(path, spheroidFolder, timeFolder, zRatio, rNoyau, dCells, pxtoum, channels, minmass)
#      91
#      92     Sph.NucFrame.to_csv(path + r'\\' + 'Spheroids' +
# ---> 93         '\\SpheroidFrame_' + spheroidFolder + r'_' +  timeFolder + '.csv')
#      94
#      95     print('refine the analysis over the spheroid')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     200                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     201
# --> 202             self._save()
#     203
#     204         finally:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     322                 break
#     323
# --> 324             self._save_chunk(start_i, end_i)
#     325
#     326     def _save_chunk(self, start_i, end_i):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     354         )
#     355
# --> 356         libwriters.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#
# pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# OSError: [Errno 28] No space left on device
